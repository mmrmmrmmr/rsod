# %%
from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# # Train the model
# results = model.train(data='/home/mamingrui/sod/ultralytics-main/ultralytics/cfg/datasets/VisDrone.yaml', epochs=200, imgsz=640, batch=32)

# model = YOLO('/home/mamingrui/sod/ultralytics-main/runs/detect/train2/weights/best.pt')  # load a pretrained model (recommended for training)

# Train the model
# results = model.val(data='/home/mamingrui/sod/ultralytics-main/ultralytics/cfg/datasets/VisDrone.yaml', epochs=200, imgsz=640, batch=32)
# result = model.predict(source="/home/mamingrui/sod/visdrone/images/val", device="1", save=True)

model = YOLO("/home/mamingrui/sod/ultralytics-main/ultralytics/cfg/models/v8/yolov8_try.yaml", task='detect', pretrained=True)
# model._load("/home/mamingrui/sod/ultralytics-main/yolov8n.pt")
import torch
state = torch.load("/home/mamingrui/sod/ultralytics-main/yolov8n.pt")
# x = torch.rand(1,3,640,640)
# y = model(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/mamingrui/sod/ultralytics-main/test.py:15
#       1 from ultralytics import YOLO
#       3 # Load a model
#       4 # model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
#       5
#    (...)
#      12 # results = model.val(data='/home/mamingrui/sod/ultralytics-main/ultralytics/cfg/datasets/VisDrone.yaml', epochs=200, imgsz=640, batch=32)
#      13 # result = model.predict(source="/home/mamingrui/sod/visdrone/images/val", device="1", save=True)
# ---> 15 model = YOLO("/home/mamingrui/sod/ultralytics-main/ultralytics/cfg/models/v8/yolov8_try.yaml", task='detect', pretrained=True)
#      16 # model._load("/home/mamingrui/sod/ultralytics-main/yolov8n.pt")
#      17 import torch
#
# TypeError: __init__() got an unexpected keyword argument 'pretrained'

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# # Train the model
# results = model.train(data='/home/mamingrui/sod/ultralytics-main/ultralytics/cfg/datasets/VisDrone.yaml', epochs=200, imgsz=640, batch=32)

# model = YOLO('/home/mamingrui/sod/ultralytics-main/runs/detect/train2/weights/best.pt')  # load a pretrained model (recommended for training)

# Train the model
# results = model.val(data='/home/mamingrui/sod/ultralytics-main/ultralytics/cfg/datasets/VisDrone.yaml', epochs=200, imgsz=640, batch=32)
# result = model.predict(source="/home/mamingrui/sod/visdrone/images/val", device="1", save=True)

model = YOLO("/home/mamingrui/sod/ultralytics-main/ultralytics/cfg/models/v8/yolov8_try.yaml", task='detect')
# model._load("/home/mamingrui/sod/ultralytics-main/yolov8n.pt")
import torch
state = torch.load("/home/mamingrui/sod/ultralytics-main/yolov8n.pt")
# x = torch.rand(1,3,640,640)
# y = model(x)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.

# %%
state
# Out:
# {'epoch': -1,
#  'best_fitness': None,
#  'model': DetectionModel(
#    (model): Sequential(
#      (0): Conv(
#        (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (1): Conv(
#        (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#        (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#        (act): SiLU(inplace=True)
#      )
#      (2): C2f(
#        (cv1): Conv(
#          (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#          (act): SiLU(inplace=True)
#        )
#        (cv2): Conv(
#          (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
state = state.model()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 state = state.model()
#
# AttributeError: 'dict' object has no attribute 'model'

# %%
state = state['model']

# %%
state
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
state_d = state.state_dict()

# %%
state_d
# Out:
# OrderedDict([('model.0.conv.weight',
#               tensor([[[[-1.1523e-01, -1.0582e-02,  1.0693e-01],
#                         [-3.6816e-01,  3.3447e-02,  3.8745e-01],
#                         [-3.3716e-01, -1.3680e-02,  3.1201e-01]],
#
#                        [[-1.4233e-01,  9.7656e-03,  1.5222e-01],
#                         [-4.8999e-01,  2.7908e-02,  4.6021e-01],
#                         [-3.7256e-01, -2.7542e-03,  3.4814e-01]],
#
#                        [[-4.9866e-02, -1.4900e-02,  2.4887e-02],
#                         [-2.1375e-01,  3.2898e-02,  1.9385e-01],
#                         [-1.5344e-01,  3.1113e-02,  1.5649e-01]]],
#
#
#                       [[[ 1.2283e-02,  1.8890e-02,  8.2321e-03],
#                         [-2.7218e-03, -2.3987e-02,  2.9926e-03],
#                         [-1.7059e-02, -1.4148e-01, -1.7426e-02]],
#
#                        [[-9.5062e-03,  1.2146e-02,  8.6975e-04],
#                         [-7.3242e-03, -2.6993e-02, -5.9357e-03],
# ...

# %%
model.model
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
model_s = model.model.state_dict()

# %%
model_s
# Out:
# OrderedDict([('model.0.conv.weight',
#               tensor([[[[-1.8062e-01,  1.7882e-01,  6.8303e-02],
#                         [-1.1510e-01, -8.1577e-02,  1.6701e-01],
#                         [ 6.0271e-02, -3.1590e-02,  1.7564e-01]],
#
#                        [[-1.5463e-01, -4.1006e-02,  1.7319e-01],
#                         [ 1.8260e-01, -6.6256e-02, -3.5878e-02],
#                         [ 1.4173e-03, -4.3741e-02,  7.9642e-02]],
#
#                        [[ 7.3495e-02, -1.9221e-01,  7.3444e-02],
#                         [ 6.1645e-02, -1.6170e-01, -1.6039e-01],
#                         [ 1.7424e-01, -1.0181e-01, -1.1661e-01]]],
#
#
#                       [[[ 1.6092e-01, -1.7523e-01, -1.0292e-01],
#                         [ 1.1082e-01,  6.1530e-02, -2.9034e-02],
#                         [ 1.4086e-01,  1.0194e-01, -5.2751e-02]],
#
#                        [[-7.7174e-02,  8.3854e-02,  1.7151e-01],
#                         [ 1.1411e-01, -1.2363e-01,  4.1352e-02],
# ...

# %%
model.model.load_state_dict(state_d)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.model.load_state_dict(state_d)
#
# File ~/.conda/envs/frame/lib/python3.9/site-packages/torch/nn/modules/module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for DetectionModel:
# ...

# %%
model.model.load_state_dict(state_d, strict=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.model.load_state_dict(state_d, strict=False)
#
# File ~/.conda/envs/frame/lib/python3.9/site-packages/torch/nn/modules/module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for DetectionModel:
# ...

# %%
state_d
# Out:
# OrderedDict([('model.0.conv.weight',
#               tensor([[[[-1.1523e-01, -1.0582e-02,  1.0693e-01],
#                         [-3.6816e-01,  3.3447e-02,  3.8745e-01],
#                         [-3.3716e-01, -1.3680e-02,  3.1201e-01]],
#
#                        [[-1.4233e-01,  9.7656e-03,  1.5222e-01],
#                         [-4.8999e-01,  2.7908e-02,  4.6021e-01],
#                         [-3.7256e-01, -2.7542e-03,  3.4814e-01]],
#
#                        [[-4.9866e-02, -1.4900e-02,  2.4887e-02],
#                         [-2.1375e-01,  3.2898e-02,  1.9385e-01],
#                         [-1.5344e-01,  3.1113e-02,  1.5649e-01]]],
#
#
#                       [[[ 1.2283e-02,  1.8890e-02,  8.2321e-03],
#                         [-2.7218e-03, -2.3987e-02,  2.9926e-03],
#                         [-1.7059e-02, -1.4148e-01, -1.7426e-02]],
#
#                        [[-9.5062e-03,  1.2146e-02,  8.6975e-04],
#                         [-7.3242e-03, -2.6993e-02, -5.9357e-03],
# ...

# %%
state
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
s = state[0:22]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s = state[0:22]
#
# TypeError: 'DetectionModel' object is not subscriptable

# %%
state
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
ss = state.model[0:22]

# %%
ss
# Out:
# Sequential(
#   (0): Conv(
#     (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (1): Conv(
#     (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (2): C2f(
#     (cv1): Conv(
#       (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (m): ModuleList(
# ...

# %%
ss_s = ss.state_dict()

# %%
ss_s
# Out:
# OrderedDict([('0.conv.weight',
#               tensor([[[[-1.1523e-01, -1.0582e-02,  1.0693e-01],
#                         [-3.6816e-01,  3.3447e-02,  3.8745e-01],
#                         [-3.3716e-01, -1.3680e-02,  3.1201e-01]],
#
#                        [[-1.4233e-01,  9.7656e-03,  1.5222e-01],
#                         [-4.8999e-01,  2.7908e-02,  4.6021e-01],
#                         [-3.7256e-01, -2.7542e-03,  3.4814e-01]],
#
#                        [[-4.9866e-02, -1.4900e-02,  2.4887e-02],
#                         [-2.1375e-01,  3.2898e-02,  1.9385e-01],
#                         [-1.5344e-01,  3.1113e-02,  1.5649e-01]]],
#
#
#                       [[[ 1.2283e-02,  1.8890e-02,  8.2321e-03],
#                         [-2.7218e-03, -2.3987e-02,  2.9926e-03],
#                         [-1.7059e-02, -1.4148e-01, -1.7426e-02]],
#
#                        [[-9.5062e-03,  1.2146e-02,  8.6975e-04],
#                         [-7.3242e-03, -2.6993e-02, -5.9357e-03],
# ...

# %%
model.modle
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 model.modle
#
# File ~/.conda/envs/frame/lib/python3.9/site-packages/torch/nn/modules/module.py:1695, in Module.__getattr__(self, name)
#    1693     if name in modules:
#    1694         return modules[name]
# -> 1695 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'YOLO' object has no attribute 'modle'

# %%
model.model
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
model.model.model
# Out:
# Sequential(
#   (0): Conv(
#     (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (1): Conv(
#     (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#     (act): SiLU(inplace=True)
#   )
#   (2): C2f(
#     (cv1): Conv(
#       (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (cv2): Conv(
#       (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (m): ModuleList(
# ...

# %%
model.model.model.load_state_dict(ss_s)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 model.model.model.load_state_dict(ss_s)
#
# File ~/.conda/envs/frame/lib/python3.9/site-packages/torch/nn/modules/module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Sequential:
# ...

# %%
mmm = model.model.model.state_dict()

# %%
mmm
# Out:
# OrderedDict([('0.conv.weight',
#               tensor([[[[-1.1523e-01, -1.0582e-02,  1.0693e-01],
#                         [-3.6816e-01,  3.3447e-02,  3.8745e-01],
#                         [-3.3716e-01, -1.3680e-02,  3.1201e-01]],
#
#                        [[-1.4233e-01,  9.7656e-03,  1.5222e-01],
#                         [-4.8999e-01,  2.7908e-02,  4.6021e-01],
#                         [-3.7256e-01, -2.7542e-03,  3.4814e-01]],
#
#                        [[-4.9866e-02, -1.4900e-02,  2.4887e-02],
#                         [-2.1375e-01,  3.2898e-02,  1.9385e-01],
#                         [-1.5344e-01,  3.1113e-02,  1.5649e-01]]],
#
#
#                       [[[ 1.2283e-02,  1.8890e-02,  8.2321e-03],
#                         [-2.7218e-03, -2.3987e-02,  2.9926e-03],
#                         [-1.7059e-02, -1.4148e-01, -1.7426e-02]],
#
#                        [[-9.5062e-03,  1.2146e-02,  8.6975e-04],
#                         [-7.3242e-03, -2.6993e-02, -5.9357e-03],
# ...

# %%
model.model.model.load_state_dict(ss_s)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 model.model.model.load_state_dict(ss_s)
#
# File ~/.conda/envs/frame/lib/python3.9/site-packages/torch/nn/modules/module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Sequential:
# ...

# %%
model.model.model.load_state_dict(ss_s,strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['22.cv2.0.0.conv.weight', '22.cv2.0.0.bn.weight', '22.cv2.0.0.bn.bias', '22.cv2.0.0.bn.running_mean', '22.cv2.0.0.bn.running_var', '22.cv2.0.1.conv.weight', '22.cv2.0.1.bn.weight', '22.cv2.0.1.bn.bias', '22.cv2.0.1.bn.running_mean', '22.cv2.0.1.bn.running_var', '22.cv2.0.2.weight', '22.cv2.0.2.bias', '22.cv2.1.0.conv.weight', '22.cv2.1.0.bn.weight', '22.cv2.1.0.bn.bias', '22.cv2.1.0.bn.running_mean', '22.cv2.1.0.bn.running_var', '22.cv2.1.1.conv.weight', '22.cv2.1.1.bn.weight', '22.cv2.1.1.bn.bias', '22.cv2.1.1.bn.running_mean', '22.cv2.1.1.bn.running_var', '22.cv2.1.2.weight', '22.cv2.1.2.bias', '22.cv2.2.0.conv.weight', '22.cv2.2.0.bn.weight', '22.cv2.2.0.bn.bias', '22.cv2.2.0.bn.running_mean', '22.cv2.2.0.bn.running_var', '22.cv2.2.1.conv.weight', '22.cv2.2.1.bn.weight', '22.cv2.2.1.bn.bias', '22.cv2.2.1.bn.running_mean', '22.cv2.2.1.bn.running_var', '22.cv2.2.2.weight', '22.cv2.2.2.bias', '22.cv2.3.0.conv.weight', '22.cv2.3.0.bn.weight', '22.cv2.3.
# ...
